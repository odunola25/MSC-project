# %% [markdown]
# <a href="https://colab.research.google.com/github/odunola25/MSC-project/blob/work/InceptionV3_Final_Batch_64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, log_loss, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

train_dir = '/content/drive/MyDrive/Colab Notebooks/Odunola Thesis/Brain Tumor MRI Dataset/Training'
test_dir = '/content/drive/MyDrive/Colab Notebooks/Odunola Thesis/Brain Tumor MRI Dataset/Testing'

image_size = (224, 224)
batch_size = 64

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    shuffle = False,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
# Load the pre-trained MobileNet model
inception_base = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

from tensorflow.keras import Model, Input

# Define the model using the Functional API
inputs = Input(shape=(224, 224, 3))
x = inception_base(inputs, training=False)  # Use 'training=False' to keep batch norm and dropout layers in inference mode
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = Dropout(0.5)(x)
outputs = Dense(4, activation='softmax')(x)

inception_model = Model(inputs, outputs)

# Print model summary
inception_model.summary()

# Fine-tune the MobileNet model
fine_tune_at_inception = 100
inception_base.trainable = True  # Make all layers trainable
for layer in inception_base.layers[:fine_tune_at_inception]:
    layer.trainable = False  # Freeze the layers up to fine_tune_at_mobilenet

# Compile the model
inception_model.compile(
    optimizer=Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Print the summary of the model after compiling
#inception_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ inception_v3 (Functional)            │ (None, 5, 5, 2048)          │      21,802,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_94               │ (None, 2048)                │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       2,098,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           4,100 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,913,252 (91.22 MB)
#  Trainable params: 23,874,724 (91.07 MB)
#  Non-trainable params: 38,528 (150.50 KB)

# %%
# Set up callbacks for InceptionV3
early_stopping_inception = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)
model_checkpoint_inception = ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr_inception = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1)

# Train the MobileNet model
history_inception = inception_model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=100,
    callbacks=[early_stopping_inception, model_checkpoint_inception, reduce_lr_inception],
    verbose=1
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21s/step - accuracy: 0.4018 - loss: 3.0151
# Epoch 1: val_loss improved from inf to 2.16906, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2662s 27s/step - accuracy: 0.4031 - loss: 3.0114 - val_accuracy: 0.7246 - val_loss: 2.1691 - learning_rate: 1.0000e-05
# Epoch 2/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6951 - loss: 2.2051
# Epoch 2: val_loss improved from 2.16906 to 1.89258, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.6954 - loss: 2.2043 - val_accuracy: 0.7986 - val_loss: 1.8926 - learning_rate: 1.0000e-05
# Epoch 3/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8040 - loss: 1.9168
# Epoch 3: val_loss improved from 1.89258 to 1.81248, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.8041 - loss: 1.9166 - val_accuracy: 0.8322 - val_loss: 1.8125 - learning_rate: 1.0000e-05
# Epoch 4/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8276 - loss: 1.8338
# Epoch 4: val_loss improved from 1.81248 to 1.77027, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.8277 - loss: 1.8337 - val_accuracy: 0.8482 - val_loss: 1.7703 - learning_rate: 1.0000e-05
# Epoch 5/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8519 - loss: 1.7813
# Epoch 5: val_loss improved from 1.77027 to 1.72124, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.8519 - loss: 1.7812 - val_accuracy: 0.8650 - val_loss: 1.7212 - learning_rate: 1.0000e-05
# Epoch 6/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8767 - loss: 1.7225
# Epoch 6: val_loss improved from 1.72124 to 1.68312, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8768 - loss: 1.7222 - val_accuracy: 0.8825 - val_loss: 1.6831 - learning_rate: 1.0000e-05
# Epoch 7/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8990 - loss: 1.6389
# Epoch 7: val_loss improved from 1.68312 to 1.64145, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.8990 - loss: 1.6391 - val_accuracy: 0.9039 - val_loss: 1.6415 - learning_rate: 1.0000e-05
# Epoch 8/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8939 - loss: 1.6623
# Epoch 8: val_loss improved from 1.64145 to 1.60751, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.8940 - loss: 1.6621 - val_accuracy: 0.9108 - val_loss: 1.6075 - learning_rate: 1.0000e-05
# Epoch 9/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 990ms/step - accuracy: 0.9117 - loss: 1.6174
# Epoch 9: val_loss improved from 1.60751 to 1.58460, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9116 - loss: 1.6173 - val_accuracy: 0.9191 - val_loss: 1.5846 - learning_rate: 1.0000e-05
# Epoch 10/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9140 - loss: 1.5787
# Epoch 10: val_loss improved from 1.58460 to 1.55892, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.9141 - loss: 1.5786 - val_accuracy: 0.9306 - val_loss: 1.5589 - learning_rate: 1.0000e-05
# Epoch 11/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 997ms/step - accuracy: 0.9265 - loss: 1.5646
# Epoch 11: val_loss improved from 1.55892 to 1.54217, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9265 - loss: 1.5646 - val_accuracy: 0.9336 - val_loss: 1.5422 - learning_rate: 1.0000e-05
# Epoch 12/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9266 - loss: 1.5459
# Epoch 12: val_loss improved from 1.54217 to 1.51727, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 133s 1s/step - accuracy: 0.9266 - loss: 1.5458 - val_accuracy: 0.9397 - val_loss: 1.5173 - learning_rate: 1.0000e-05
# Epoch 13/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9318 - loss: 1.5293
# Epoch 13: val_loss improved from 1.51727 to 1.50158, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.9318 - loss: 1.5292 - val_accuracy: 0.9443 - val_loss: 1.5016 - learning_rate: 1.0000e-05
# Epoch 14/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9380 - loss: 1.5081
# Epoch 14: val_loss improved from 1.50158 to 1.48551, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9380 - loss: 1.5080 - val_accuracy: 0.9451 - val_loss: 1.4855 - learning_rate: 1.0000e-05
# Epoch 15/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9522 - loss: 1.4766
# Epoch 15: val_loss improved from 1.48551 to 1.46975, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9522 - loss: 1.4766 - val_accuracy: 0.9558 - val_loss: 1.4698 - learning_rate: 1.0000e-05
# Epoch 16/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 999ms/step - accuracy: 0.9474 - loss: 1.4730
# Epoch 16: val_loss improved from 1.46975 to 1.46139, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9474 - loss: 1.4729 - val_accuracy: 0.9558 - val_loss: 1.4614 - learning_rate: 1.0000e-05
# Epoch 17/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9509 - loss: 1.4682
# Epoch 17: val_loss improved from 1.46139 to 1.45759, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9509 - loss: 1.4681 - val_accuracy: 0.9512 - val_loss: 1.4576 - learning_rate: 1.0000e-05
# Epoch 18/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9599 - loss: 1.4474
# Epoch 18: val_loss improved from 1.45759 to 1.43521, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9599 - loss: 1.4474 - val_accuracy: 0.9596 - val_loss: 1.4352 - learning_rate: 1.0000e-05
# Epoch 19/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9547 - loss: 1.4452
# Epoch 19: val_loss improved from 1.43521 to 1.42441, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9547 - loss: 1.4452 - val_accuracy: 0.9619 - val_loss: 1.4244 - learning_rate: 1.0000e-05
# Epoch 20/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9577 - loss: 1.4276
# Epoch 20: val_loss improved from 1.42441 to 1.41399, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9577 - loss: 1.4276 - val_accuracy: 0.9672 - val_loss: 1.4140 - learning_rate: 1.0000e-05
# Epoch 21/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9679 - loss: 1.4146
# Epoch 21: val_loss improved from 1.41399 to 1.40407, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9679 - loss: 1.4146 - val_accuracy: 0.9664 - val_loss: 1.4041 - learning_rate: 1.0000e-05
# Epoch 22/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9673 - loss: 1.4062
# Epoch 22: val_loss improved from 1.40407 to 1.39437, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9673 - loss: 1.4062 - val_accuracy: 0.9725 - val_loss: 1.3944 - learning_rate: 1.0000e-05
# Epoch 23/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9624 - loss: 1.4147
# Epoch 23: val_loss improved from 1.39437 to 1.38670, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9625 - loss: 1.4146 - val_accuracy: 0.9764 - val_loss: 1.3867 - learning_rate: 1.0000e-05
# Epoch 24/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9707 - loss: 1.3938
# Epoch 24: val_loss improved from 1.38670 to 1.37095, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9707 - loss: 1.3938 - val_accuracy: 0.9779 - val_loss: 1.3710 - learning_rate: 1.0000e-05
# Epoch 25/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9760 - loss: 1.3670
# Epoch 25: val_loss improved from 1.37095 to 1.36910, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9760 - loss: 1.3670 - val_accuracy: 0.9779 - val_loss: 1.3691 - learning_rate: 1.0000e-05
# Epoch 26/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - accuracy: 0.9738 - loss: 1.3787
# Epoch 26: val_loss improved from 1.36910 to 1.35813, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9738 - loss: 1.3786 - val_accuracy: 0.9786 - val_loss: 1.3581 - learning_rate: 1.0000e-05
# Epoch 27/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9811 - loss: 1.3534
# Epoch 27: val_loss improved from 1.35813 to 1.35460, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9811 - loss: 1.3535 - val_accuracy: 0.9794 - val_loss: 1.3546 - learning_rate: 1.0000e-05
# Epoch 28/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9792 - loss: 1.3537
# Epoch 28: val_loss improved from 1.35460 to 1.34242, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9791 - loss: 1.3538 - val_accuracy: 0.9832 - val_loss: 1.3424 - learning_rate: 1.0000e-05
# Epoch 29/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9755 - loss: 1.3568
# Epoch 29: val_loss improved from 1.34242 to 1.34036, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9755 - loss: 1.3568 - val_accuracy: 0.9840 - val_loss: 1.3404 - learning_rate: 1.0000e-05
# Epoch 30/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9801 - loss: 1.3401
# Epoch 30: val_loss improved from 1.34036 to 1.32759, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9801 - loss: 1.3400 - val_accuracy: 0.9847 - val_loss: 1.3276 - learning_rate: 1.0000e-05
# Epoch 31/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9803 - loss: 1.3392
# Epoch 31: val_loss improved from 1.32759 to 1.32452, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9802 - loss: 1.3392 - val_accuracy: 0.9825 - val_loss: 1.3245 - learning_rate: 1.0000e-05
# Epoch 32/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9824 - loss: 1.3225
# Epoch 32: val_loss improved from 1.32452 to 1.31628, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.9824 - loss: 1.3225 - val_accuracy: 0.9840 - val_loss: 1.3163 - learning_rate: 1.0000e-05
# Epoch 33/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9815 - loss: 1.3216
# Epoch 33: val_loss improved from 1.31628 to 1.31608, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9815 - loss: 1.3216 - val_accuracy: 0.9825 - val_loss: 1.3161 - learning_rate: 1.0000e-05
# Epoch 34/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9854 - loss: 1.3101
# Epoch 34: val_loss improved from 1.31608 to 1.30697, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9854 - loss: 1.3101 - val_accuracy: 0.9825 - val_loss: 1.3070 - learning_rate: 1.0000e-05
# Epoch 35/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9843 - loss: 1.3038
# Epoch 35: val_loss improved from 1.30697 to 1.30406, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9843 - loss: 1.3037 - val_accuracy: 0.9840 - val_loss: 1.3041 - learning_rate: 1.0000e-05
# Epoch 36/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9862 - loss: 1.2967
# Epoch 36: val_loss improved from 1.30406 to 1.29213, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9862 - loss: 1.2967 - val_accuracy: 0.9863 - val_loss: 1.2921 - learning_rate: 1.0000e-05
# Epoch 37/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9831 - loss: 1.2991
# Epoch 37: val_loss improved from 1.29213 to 1.28824, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9832 - loss: 1.2990 - val_accuracy: 0.9863 - val_loss: 1.2882 - learning_rate: 1.0000e-05
# Epoch 38/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9882 - loss: 1.2868
# Epoch 38: val_loss improved from 1.28824 to 1.27993, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9882 - loss: 1.2868 - val_accuracy: 0.9870 - val_loss: 1.2799 - learning_rate: 1.0000e-05
# Epoch 39/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 1.2838
# Epoch 39: val_loss improved from 1.27993 to 1.27675, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9842 - loss: 1.2838 - val_accuracy: 0.9870 - val_loss: 1.2768 - learning_rate: 1.0000e-05
# Epoch 40/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 1.2655
# Epoch 40: val_loss did not improve from 1.27675
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.9923 - loss: 1.2654 - val_accuracy: 0.9870 - val_loss: 1.2780 - learning_rate: 1.0000e-05
# Epoch 41/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9902 - loss: 1.2576
# Epoch 41: val_loss improved from 1.27675 to 1.26716, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9902 - loss: 1.2576 - val_accuracy: 0.9863 - val_loss: 1.2672 - learning_rate: 1.0000e-05
# Epoch 42/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9910 - loss: 1.2504
# Epoch 42: val_loss improved from 1.26716 to 1.26381, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 135s 1s/step - accuracy: 0.9910 - loss: 1.2504 - val_accuracy: 0.9847 - val_loss: 1.2638 - learning_rate: 1.0000e-05
# Epoch 43/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9869 - loss: 1.2577
# Epoch 43: val_loss improved from 1.26381 to 1.25825, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.9869 - loss: 1.2577 - val_accuracy: 0.9870 - val_loss: 1.2583 - learning_rate: 1.0000e-05
# Epoch 44/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9898 - loss: 1.2424
# Epoch 44: val_loss improved from 1.25825 to 1.25266, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9898 - loss: 1.2424 - val_accuracy: 0.9863 - val_loss: 1.2527 - learning_rate: 1.0000e-05
# Epoch 45/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9886 - loss: 1.2378
# Epoch 45: val_loss improved from 1.25266 to 1.23921, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9886 - loss: 1.2378 - val_accuracy: 0.9886 - val_loss: 1.2392 - learning_rate: 1.0000e-05
# Epoch 46/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 1.2303
# Epoch 46: val_loss improved from 1.23921 to 1.22851, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9923 - loss: 1.2303 - val_accuracy: 0.9893 - val_loss: 1.2285 - learning_rate: 1.0000e-05
# Epoch 47/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9934 - loss: 1.2159
# Epoch 47: val_loss improved from 1.22851 to 1.22310, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.9934 - loss: 1.2160 - val_accuracy: 0.9901 - val_loss: 1.2231 - learning_rate: 1.0000e-05
# Epoch 48/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9914 - loss: 1.2207
# Epoch 48: val_loss improved from 1.22310 to 1.22019, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9915 - loss: 1.2207 - val_accuracy: 0.9901 - val_loss: 1.2202 - learning_rate: 1.0000e-05
# Epoch 49/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 1.2024
# Epoch 49: val_loss improved from 1.22019 to 1.21216, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9946 - loss: 1.2024 - val_accuracy: 0.9886 - val_loss: 1.2122 - learning_rate: 1.0000e-05
# Epoch 50/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9905 - loss: 1.2084
# Epoch 50: val_loss improved from 1.21216 to 1.20507, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9906 - loss: 1.2083 - val_accuracy: 0.9908 - val_loss: 1.2051 - learning_rate: 1.0000e-05
# Epoch 51/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9872 - loss: 1.2010
# Epoch 51: val_loss improved from 1.20507 to 1.19856, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9872 - loss: 1.2010 - val_accuracy: 0.9908 - val_loss: 1.1986 - learning_rate: 1.0000e-05
# Epoch 52/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9899 - loss: 1.1941
# Epoch 52: val_loss improved from 1.19856 to 1.19180, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9899 - loss: 1.1940 - val_accuracy: 0.9916 - val_loss: 1.1918 - learning_rate: 1.0000e-05
# Epoch 53/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9923 - loss: 1.1775
# Epoch 53: val_loss improved from 1.19180 to 1.18625, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9924 - loss: 1.1774 - val_accuracy: 0.9908 - val_loss: 1.1863 - learning_rate: 1.0000e-05
# Epoch 54/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9907 - loss: 1.1751
# Epoch 54: val_loss improved from 1.18625 to 1.17900, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9907 - loss: 1.1752 - val_accuracy: 0.9893 - val_loss: 1.1790 - learning_rate: 1.0000e-05
# Epoch 55/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9934 - loss: 1.1649
# Epoch 55: val_loss improved from 1.17900 to 1.17496, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - accuracy: 0.9934 - loss: 1.1649 - val_accuracy: 0.9878 - val_loss: 1.1750 - learning_rate: 1.0000e-05
# Epoch 56/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9939 - loss: 1.1525
# Epoch 56: val_loss improved from 1.17496 to 1.16826, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9939 - loss: 1.1526 - val_accuracy: 0.9908 - val_loss: 1.1683 - learning_rate: 1.0000e-05
# Epoch 57/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9961 - loss: 1.1466
# Epoch 57: val_loss improved from 1.16826 to 1.16049, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9960 - loss: 1.1466 - val_accuracy: 0.9924 - val_loss: 1.1605 - learning_rate: 1.0000e-05
# Epoch 58/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9943 - loss: 1.1391
# Epoch 58: val_loss improved from 1.16049 to 1.15300, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9943 - loss: 1.1391 - val_accuracy: 0.9908 - val_loss: 1.1530 - learning_rate: 1.0000e-05
# Epoch 59/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9951 - loss: 1.1304
# Epoch 59: val_loss improved from 1.15300 to 1.14003, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.9951 - loss: 1.1304 - val_accuracy: 0.9901 - val_loss: 1.1400 - learning_rate: 1.0000e-05
# Epoch 60/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 1.1259
# Epoch 60: val_loss improved from 1.14003 to 1.13724, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9947 - loss: 1.1260 - val_accuracy: 0.9878 - val_loss: 1.1372 - learning_rate: 1.0000e-05
# Epoch 61/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9935 - loss: 1.1222
# Epoch 61: val_loss improved from 1.13724 to 1.12575, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9935 - loss: 1.1222 - val_accuracy: 0.9924 - val_loss: 1.1258 - learning_rate: 1.0000e-05
# Epoch 62/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9953 - loss: 1.1094
# Epoch 62: val_loss improved from 1.12575 to 1.11951, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9953 - loss: 1.1094 - val_accuracy: 0.9924 - val_loss: 1.1195 - learning_rate: 1.0000e-05
# Epoch 63/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 1.0999
# Epoch 63: val_loss improved from 1.11951 to 1.11435, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9946 - loss: 1.0999 - val_accuracy: 0.9901 - val_loss: 1.1144 - learning_rate: 1.0000e-05
# Epoch 64/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 1.0937
# Epoch 64: val_loss improved from 1.11435 to 1.10191, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9945 - loss: 1.0937 - val_accuracy: 0.9939 - val_loss: 1.1019 - learning_rate: 1.0000e-05
# Epoch 65/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - loss: 1.0909
# Epoch 65: val_loss improved from 1.10191 to 1.09565, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9947 - loss: 1.0909 - val_accuracy: 0.9924 - val_loss: 1.0956 - learning_rate: 1.0000e-05
# Epoch 66/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9957 - loss: 1.0770
# Epoch 66: val_loss improved from 1.09565 to 1.08914, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9957 - loss: 1.0770 - val_accuracy: 0.9924 - val_loss: 1.0891 - learning_rate: 1.0000e-05
# Epoch 67/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9980 - loss: 1.0654
# Epoch 67: val_loss improved from 1.08914 to 1.08166, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9980 - loss: 1.0654 - val_accuracy: 0.9939 - val_loss: 1.0817 - learning_rate: 1.0000e-05
# Epoch 68/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9946 - loss: 1.0613
# Epoch 68: val_loss improved from 1.08166 to 1.07294, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9946 - loss: 1.0613 - val_accuracy: 0.9924 - val_loss: 1.0729 - learning_rate: 1.0000e-05
# Epoch 69/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9956 - loss: 1.0509
# Epoch 69: val_loss improved from 1.07294 to 1.06832, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9956 - loss: 1.0509 - val_accuracy: 0.9916 - val_loss: 1.0683 - learning_rate: 1.0000e-05
# Epoch 70/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9957 - loss: 1.0435
# Epoch 70: val_loss improved from 1.06832 to 1.06340, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9957 - loss: 1.0435 - val_accuracy: 0.9908 - val_loss: 1.0634 - learning_rate: 1.0000e-05
# Epoch 71/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - loss: 1.0456
# Epoch 71: val_loss improved from 1.06340 to 1.05569, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9915 - loss: 1.0455 - val_accuracy: 0.9908 - val_loss: 1.0557 - learning_rate: 1.0000e-05
# Epoch 72/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9963 - loss: 1.0266
# Epoch 72: val_loss improved from 1.05569 to 1.04745, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9963 - loss: 1.0266 - val_accuracy: 0.9901 - val_loss: 1.0475 - learning_rate: 1.0000e-05
# Epoch 73/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9950 - loss: 1.0187
# Epoch 73: val_loss improved from 1.04745 to 1.04190, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9950 - loss: 1.0187 - val_accuracy: 0.9886 - val_loss: 1.0419 - learning_rate: 1.0000e-05
# Epoch 74/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9962 - loss: 1.0089
# Epoch 74: val_loss improved from 1.04190 to 1.02508, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9962 - loss: 1.0089 - val_accuracy: 0.9916 - val_loss: 1.0251 - learning_rate: 1.0000e-05
# Epoch 75/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9954 - loss: 1.0031
# Epoch 75: val_loss improved from 1.02508 to 1.01979, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.9954 - loss: 1.0031 - val_accuracy: 0.9908 - val_loss: 1.0198 - learning_rate: 1.0000e-05
# Epoch 76/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9952 - loss: 0.9939
# Epoch 76: val_loss improved from 1.01979 to 1.00865, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9952 - loss: 0.9939 - val_accuracy: 0.9908 - val_loss: 1.0087 - learning_rate: 1.0000e-05
# Epoch 77/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9938 - loss: 0.9899
# Epoch 77: val_loss improved from 1.00865 to 0.99984, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9938 - loss: 0.9899 - val_accuracy: 0.9924 - val_loss: 0.9998 - learning_rate: 1.0000e-05
# Epoch 78/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9951 - loss: 0.9775
# Epoch 78: val_loss improved from 0.99984 to 0.99521, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9951 - loss: 0.9775 - val_accuracy: 0.9908 - val_loss: 0.9952 - learning_rate: 1.0000e-05
# Epoch 79/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9952 - loss: 0.9708
# Epoch 79: val_loss improved from 0.99521 to 0.98667, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9952 - loss: 0.9707 - val_accuracy: 0.9893 - val_loss: 0.9867 - learning_rate: 1.0000e-05
# Epoch 80/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9943 - loss: 0.9623
# Epoch 80: val_loss improved from 0.98667 to 0.97841, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9943 - loss: 0.9622 - val_accuracy: 0.9908 - val_loss: 0.9784 - learning_rate: 1.0000e-05
# Epoch 81/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9977 - loss: 0.9460
# Epoch 81: val_loss improved from 0.97841 to 0.97288, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9977 - loss: 0.9460 - val_accuracy: 0.9901 - val_loss: 0.9729 - learning_rate: 1.0000e-05
# Epoch 82/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9945 - loss: 0.9456
# Epoch 82: val_loss improved from 0.97288 to 0.96088, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9945 - loss: 0.9455 - val_accuracy: 0.9901 - val_loss: 0.9609 - learning_rate: 1.0000e-05
# Epoch 83/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9966 - loss: 0.9332
# Epoch 83: val_loss improved from 0.96088 to 0.95050, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9966 - loss: 0.9332 - val_accuracy: 0.9908 - val_loss: 0.9505 - learning_rate: 1.0000e-05
# Epoch 84/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9983 - loss: 0.9216
# Epoch 84: val_loss improved from 0.95050 to 0.94110, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9983 - loss: 0.9216 - val_accuracy: 0.9924 - val_loss: 0.9411 - learning_rate: 1.0000e-05
# Epoch 85/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9973 - loss: 0.9130
# Epoch 85: val_loss improved from 0.94110 to 0.93241, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 134s 1s/step - accuracy: 0.9973 - loss: 0.9131 - val_accuracy: 0.9916 - val_loss: 0.9324 - learning_rate: 1.0000e-05
# Epoch 86/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9957 - loss: 0.9054
# Epoch 86: val_loss improved from 0.93241 to 0.91866, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 121s 1s/step - accuracy: 0.9957 - loss: 0.9053 - val_accuracy: 0.9908 - val_loss: 0.9187 - learning_rate: 1.0000e-05
# Epoch 87/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9965 - loss: 0.8966
# Epoch 87: val_loss improved from 0.91866 to 0.91607, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9965 - loss: 0.8965 - val_accuracy: 0.9916 - val_loss: 0.9161 - learning_rate: 1.0000e-05
# Epoch 88/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9955 - loss: 0.8878
# Epoch 88: val_loss improved from 0.91607 to 0.90549, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9955 - loss: 0.8878 - val_accuracy: 0.9924 - val_loss: 0.9055 - learning_rate: 1.0000e-05
# Epoch 89/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9981 - loss: 0.8747
# Epoch 89: val_loss improved from 0.90549 to 0.88708, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.9981 - loss: 0.8746 - val_accuracy: 0.9939 - val_loss: 0.8871 - learning_rate: 1.0000e-05
# Epoch 90/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9969 - loss: 0.8727
# Epoch 90: val_loss improved from 0.88708 to 0.88221, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9969 - loss: 0.8727 - val_accuracy: 0.9939 - val_loss: 0.8822 - learning_rate: 1.0000e-05
# Epoch 91/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9980 - loss: 0.8584
# Epoch 91: val_loss improved from 0.88221 to 0.87583, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9980 - loss: 0.8584 - val_accuracy: 0.9924 - val_loss: 0.8758 - learning_rate: 1.0000e-05
# Epoch 92/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9973 - loss: 0.8489
# Epoch 92: val_loss improved from 0.87583 to 0.86185, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9973 - loss: 0.8489 - val_accuracy: 0.9924 - val_loss: 0.8618 - learning_rate: 1.0000e-05
# Epoch 93/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9978 - loss: 0.8398
# Epoch 93: val_loss improved from 0.86185 to 0.85597, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9978 - loss: 0.8398 - val_accuracy: 0.9931 - val_loss: 0.8560 - learning_rate: 1.0000e-05
# Epoch 94/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9970 - loss: 0.8328
# Epoch 94: val_loss improved from 0.85597 to 0.84904, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9970 - loss: 0.8328 - val_accuracy: 0.9931 - val_loss: 0.8490 - learning_rate: 1.0000e-05
# Epoch 95/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9969 - loss: 0.8235
# Epoch 95: val_loss improved from 0.84904 to 0.83888, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9969 - loss: 0.8235 - val_accuracy: 0.9931 - val_loss: 0.8389 - learning_rate: 1.0000e-05
# Epoch 96/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9982 - loss: 0.8108
# Epoch 96: val_loss improved from 0.83888 to 0.82968, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 128s 1s/step - accuracy: 0.9982 - loss: 0.8108 - val_accuracy: 0.9939 - val_loss: 0.8297 - learning_rate: 1.0000e-05
# Epoch 97/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9958 - loss: 0.8085
# Epoch 97: val_loss improved from 0.82968 to 0.82696, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.9958 - loss: 0.8085 - val_accuracy: 0.9908 - val_loss: 0.8270 - learning_rate: 1.0000e-05
# Epoch 98/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9973 - loss: 0.7970
# Epoch 98: val_loss improved from 0.82696 to 0.81495, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9973 - loss: 0.7969 - val_accuracy: 0.9924 - val_loss: 0.8150 - learning_rate: 1.0000e-05
# Epoch 99/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9973 - loss: 0.7878
# Epoch 99: val_loss improved from 0.81495 to 0.81109, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9973 - loss: 0.7878 - val_accuracy: 0.9908 - val_loss: 0.8111 - learning_rate: 1.0000e-05
# Epoch 100/100
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9973 - loss: 0.7782
# Epoch 100: val_loss improved from 0.81109 to 0.79588, saving model to /content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 116s 1s/step - accuracy: 0.9973 - loss: 0.7782 - val_accuracy: 0.9947 - val_loss: 0.7959 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 100.

# %%
# Plot the training and validation accuracy and loss curves
acc = history_inception.history['accuracy']
val_acc = history_inception.history['val_accuracy']
loss = history_inception.history['loss']
val_loss = history_inception.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
# Load the best model
best_model_path = '/content/drive/MyDrive/Colab Notebooks/Odunola Thesis/64_inception_fine_tuned_model.keras'

mobilenet_model_64 = tf.keras.models.load_model(best_model_path)

# %%
# Evaluate the best model
test_loss, test_accuracy = mobilenet_model_64.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 584ms/step - accuracy: 0.9946 - loss: 0.7945
# Test Accuracy: 0.9946605563163757

# %%
import os
import glob

def get_number(path):
  if not os.path.exists(path):
    return 0
  count = 0

  for current_path, dirs, files in os.walk(path):
    for dr in dirs:
      count += len(glob.glob(os.path.join(current_path,dr + "/*")))
  return count

# %%
testing_images = get_number(test_dir)

print("Number of testing samples is", testing_images)
# Out:
# Number of testing samples is 1311

# %%
Classes = ['Glioma', 'Meningioma', 'No Tumour', 'Pituitary']

# %%
from sklearn.metrics import classification_report,confusion_matrix
y_test = test_generator.classes

# predicting our model with test dataset i.e. unseen dataset
pred = mobilenet_model_64.predict(test_generator, testing_images//batch_size+1,verbose=1,).argmax(axis=1)
#print(y_test)
print(pred)
#Classification report of every label
print(classification_report(y_test, pred, target_names = Classes))
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 18s 590ms/step
# [0 0 0 ... 3 3 3]
#               precision    recall  f1-score   support
#
#       Glioma       1.00      0.99      0.99       300
#   Meningioma       0.99      0.99      0.99       306
#    No Tumour       1.00      1.00      1.00       405
#    Pituitary       0.99      0.99      0.99       300
#
#     accuracy                           0.99      1311
#    macro avg       0.99      0.99      0.99      1311
# weighted avg       0.99      0.99      0.99      1311

# %%
correct = 0
incorrect = 0
for i in range(len(y_test)):

    #print("Test Sample is: ", y_test[i], "while predicted sample is: ", pred[i])

    if y_test[i] != pred[i]:
        incorrect += 1
    else:
        correct += 1

print('Total number of test cases', ((len(y_test))))
print('Number of correct predictions', correct)
print('Number of incorrect predictions', incorrect)
# Out:
# Total number of test cases 1311
# Number of correct predictions 1304
# Number of incorrect predictions 7

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_test, pred)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=Classes, yticklabels=Classes)
plt.title('Confusion Matrix for InceptionV3_64')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
